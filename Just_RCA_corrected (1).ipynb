# %% [markdown]
# ## Corrected RCA Knowledge Base — (references cross-checked & renumbered)
#
# This version reproduces the RCA dashboard with **every reference verified against the actual source PDF** and a
# clean **two-tier citation scheme**. The verbatim quotes and exact page locations are kept in a **separate companion
# file** so the dashboard itself stays uncluttered.
#
# ### Naming convention
# - **`P1 … P9`** — **primary** peer-reviewed research sources. Each one was located and confirmed against the supplied PDF.
# - **`S1 … S7`** — **secondary** sources: textbooks, monographs, a review, a statistical method, and the dataset/taxonomy.
#
# The `Provenance` badge on each evidence row reports that source's tier (Primary / Textbook / Monograph / Review /
# Statistical / Heuristic / Dataset), so the *strength of grounding* for each mechanism is visible at a glance.

# %%
import time


def run_defect_analysis(image_path="dummy_path.png"):
    """
    Simulates the CNN image processing and classification.
    In your real pipeline, this will contain your load_wafer_array and model.predict logic.
    """
    print("Loading image and running CNN inference...")
    time.sleep(1)  # Simulating compute time

    # Simulated CNN output. Change this string to test other outputs (e.g., "Edge-Ring", "Center").
    predicted_defect = "Loc"
    confidence_score = 0.925

    print(f"\u2705 Defect Detected: {predicted_defect} (Confidence: {confidence_score*100:.1f}%)")
    print("Passing data to RCA module...")

    return predicted_defect, confidence_score


# ---------------------------------------------------------
# EXECUTE: Run the analysis and capture the results in variables
# ---------------------------------------------------------
detected_class, detected_confidence = run_defect_analysis()
# Out:
# Loading image and running CNN inference...
# ✅ Defect Detected: Loc (Confidence: 92.5%)
# Passing data to RCA module...

# %%
from IPython.display import display, HTML

# =====================================================================================
# 1. REFERENCES  (every key verified against the source PDF in hand)
#    Naming convention:
#       P1..P9  = PRIMARY peer-reviewed research sources
#       S1..S7  = SECONDARY sources (textbook / monograph / review / statistical / dataset)
#    'type' drives the colour of the provenance badge.
#    Verbatim quotes + exact page locations are kept OUT of this dashboard on purpose;
#    they live in the companion file:  Just_RCA_reference_crosscheck_v3.md
# =====================================================================================
REFERENCES = {
    # ---------- PRIMARY (P) ----------
    "P1": {"type": "Primary",
           "cite": "Emslie, A. G., Bonner, F. T., & Peck, L. G. (1958). Flow of a Viscous Liquid on a Rotating Disk. Journal of Applied Physics, 29(5), 858-862. DOI:10.1063/1.1723300"},
    "P2": {"type": "Primary",
           "cite": "Meyerhofer, D. (1978). Characteristics of resist films produced by spinning. Journal of Applied Physics, 49(7), 3993-3997. DOI:10.1063/1.325357"},
    "P3": {"type": "Primary",
           "cite": "Deaton, R., & Massoud, H. Z. (1991). Effect of thermally induced stresses on the rapid-thermal oxidation of silicon. Journal of Applied Physics, 70(7), 3588-3592. DOI:10.1063/1.349254"},
    "P4": {"type": "Primary",
           "cite": "Wang, X., Lee, H., Nam, S. K., & Kushner, M. J. (2021). Erosion of focus rings in capacitively coupled plasma etching reactors. Journal of Vacuum Science & Technology A, 39(6), 063002. DOI:10.1116/6.0001225"},
    "P5": {"type": "Primary",
           "cite": "Prasad, Y. N., Kwon, T.-Y., Kim, I.-K., Kim, I.-G., & Park, J.-G. (2011). Generation of Pad Debris during Oxide CMP Process and Its Role in Scratch Formation. Journal of The Electrochemical Society, 158(4), H394-H400. DOI:10.1149/1.3551507"},
    "P6": {"type": "Primary",
           "cite": "Stapper, C. H. (1973). Defect Density Distribution for LSI Yield Calculations. IEEE Transactions on Electron Devices, ED-20(7), 655-657."},
    "P7": {"type": "Primary",
           "cite": "Stapper, C. H., Armstrong, F. M., & Saji, K. (1983). Integrated Circuit Yield Statistics. Proceedings of the IEEE, 71(4), 453-470."},
    "P8": {"type": "Primary",
           "cite": "Mack, C. A. (1988). Understanding Focus Effects in Submicron Optical Lithography. Proc. SPIE 0922, Optical/Laser Microlithography, 135-148. DOI:10.1117/12.968418"},
    "P9": {"type": "Primary",
           "cite": "Zuo, R., Xu, Q., & Zhang, H. (2007). An inverse-flow showerhead MOVPE reactor design. Journal of Crystal Growth, 298, 425-427. DOI:10.1016/j.jcrysgro.2006.11.044  [MOVPE/III-V simulation; radial-depletion principle transferred to CVD/PVD]"},
    # ---------- SECONDARY (S) ----------
    "S1": {"type": "Textbook",
           "cite": "May, G. S., & Spanos, C. J. (2006). Fundamentals of Semiconductor Manufacturing and Process Control. Wiley-IEEE Press."},
    "S2": {"type": "Textbook",
           "cite": "Wolf, S., & Tauber, R. N. (2000). Silicon Processing for the VLSI Era, Vol. 1: Process Technology (2nd ed.). Lattice Press."},
    "S3": {"type": "Textbook",
           "cite": "Lieberman, M. A., & Lichtenberg, A. J. (2005). Principles of Plasma Discharges and Materials Processing (2nd ed.). Wiley-Interscience."},
    "S4": {"type": "Monograph",
           "cite": "Steigerwald, J. M., Murarka, S. P., & Gutmann, R. J. (1997). Chemical Mechanical Planarization of Microelectronic Materials. John Wiley & Sons."},
    "S5": {"type": "Review",
           "cite": "Zantye, P. B., Kumar, A., & Sikder, A. K. (2004). Chemical mechanical planarization for microelectronics applications. Materials Science and Engineering: R: Reports, 45(3-6), 89-220. DOI:10.1016/j.mser.2004.06.002"},
    "S6": {"type": "Statistical",
           "cite": "Hansen, M. H., Nair, V. N., & Friedman, D. J. (1997). Monitoring Wafer Map Data from IC Fabrication Processes for Spatially Clustered Defects. Technometrics, 39(3), 241-253. DOI:10.1080/00401706.1997.10485116"},
    "S7": {"type": "Dataset / taxonomy",
           "cite": "Wu, M.-J., Jang, J.-S. R., & Chen, J.-L. (2015). Wafer Map Failure Pattern Recognition and Similarity Ranking for Large-Scale Data Sets. IEEE Transactions on Semiconductor Manufacturing, 28(1), 1-12. DOI:10.1109/TSM.2014.2364237"},
}

# =====================================================================================
# 2. RCA KNOWLEDGE BASE
#    Each evidence row = [Process module, Physical mechanism, Mechanistic basis,
#                         Evidence strength, Reference key, Provenance tier]
#    Provenance tier is per-row: it reflects how strongly THIS claim is supported,
#    which can differ from the source type (e.g. a textbook cited for a Heuristic claim).
# =====================================================================================
RCA_KB = {
    "Center": {
        "description": "Failing dies concentrated in a compact cluster at the wafer center.",
        "evidence": [
            ["Photoresist spin-coat", "Dispense / spread non-uniformity", "Newtonian radial flow on the spinning wafer governs film uniformity (centre-thick if spread is incomplete)", "Medium-High", "P1", "Primary"],
            ["RTP / Anneal", "Center-to-edge thermal gradient", "Radial temperature gradient during RTP induces centre-vs-edge stress / non-uniform reaction", "Medium-High", "P3", "Primary"],
            ["Deposition (CVD/PVD)", "Center-thick / center-thin film non-uniformity", "Showerhead radial reactant depletion drives centre-to-edge thickness variation", "Medium", "P9", "Primary"],
            ["CMP", "Center over/under-polish", "Carrier-head centre-zone pressure sets a radial removal rate (Preston: RR proportional to pressure x velocity)", "Medium", "S4", "Monograph"],
        ],
        "investigations": ["Review spin-coat dispense & spread recipe", "Check chuck backside He cooling / thermal contact (RTP)", "Verify deposition centre-to-edge uniformity", "Review CMP head centre-zone pressure"],
        "corrective": ["Adjust spin-coat dispense program", "Restore chuck thermal contact / RTP radial profile", "Tune deposition showerhead / gas loading", "Rebalance CMP zonal pressure"],
        "evidence_strength": "Medium-High",
    },
    "Donut": {
        "description": "Annular band of failing dies at mid-radius; passing center and passing outer edge.",
        "evidence": [
            ["Photoresist spin-coat", "Radial non-uniformity / solvent-evaporation front", "Evaporation-controlled thinning during spin can leave a mid-radius thickness band", "Medium-High", "P2", "Primary"],
            ["CMP", "Annular (zonal) polish non-uniformity", "Retaining-ring / zonal pressure produces an annular removal band (Preston removal-rate mechanics)", "Medium-High", "S4", "Monograph"],
            ["Deposition", "Annular film-thickness band", "Radial reactant depletion under the showerhead leaves a mid-radius thickness band", "Medium", "P9", "Primary"],
            ["Etch", "Radial plasma-etch non-uniformity (gas/temperature band)", "Radial transport gradient in the reactor (NOT the vertical resist 'standing-wave' exposure effect)", "Low", "S3", "Textbook"],
        ],
        "investigations": ["Review spin-speed profile & bowl exhaust", "Inspect CMP retaining ring & zonal pressure", "Check radial gas/temperature uniformity", "Review bake-plate uniformity"],
        "corrective": ["Adjust spin-speed ramp / evaporation profile", "Replace/retune CMP retaining ring", "Rebalance radial gas/temperature", "Correct bake-plate profile"],
        "evidence_strength": "Medium",
    },
    "Edge-Loc": {
        "description": "Failing dies in a localized arc at the wafer edge (partial edge segment).",
        "evidence": [
            ["Etch / Plasma", "Localized edge plasma non-uniformity", "Localized focus-ring wear distorts the edge sheath over an arc of the perimeter", "Medium-High", "P4", "Primary"],
            ["Lithography", "Edge focus / exposure error", "Wafer-edge defocus consumes the depth-of-focus budget at the edge", "Medium-High", "P8", "Primary"],
            ["Edge handling / clamp", "Edge clamp / contact damage", "Mechanical damage at a clamp or contact point", "Medium", "S1", "Heuristic"],
            ["Edge-bead removal (EBR)", "EBR nozzle misalignment", "Mis-set EBR width removes/leaves resist at the wafer edge", "Medium", "S1", "Heuristic"],
        ],
        "investigations": ["Inspect focus ring for localized wear", "Check edge exposure focus/dose vs depth-of-focus budget", "Inspect wafer clamp pins / contact points", "Verify edge-bead-removal alignment"],
        "corrective": ["Replace/rotate focus ring", "Recalibrate edge exposure / focus offset", "Replace damaged clamp pin", "Realign EBR nozzle"],
        "evidence_strength": "Medium-High",
    },
    "Edge-Ring": {
        "description": "Failing dies forming a ring around the entire wafer edge.",
        "evidence": [
            ["Etch / Plasma", "Edge plasma / sheath non-uniformity", "Height/permittivity step at the wafer edge bends the sheath and distorts ion trajectories", "High", "S3", "Textbook"],
            ["Etch / Plasma", "Focus-ring erosion", "Ion bombardment erodes the consumable focus ring, re-introducing edge non-uniformity over its service life", "High", "P4", "Primary"],
            ["Etch / Plasma", "Edge gas-distribution effect", "Edge gas flow / chamber edge-purge non-uniformity", "Medium", "S1", "Textbook"],
            ["RTP / Anneal", "Radial thermal gradient during RTA", "Edge radiative loss creates a radial temperature gradient and edge stress", "Medium", "P3", "Primary"],
        ],
        "investigations": ["Inspect / replace focus ring", "Verify RF power stability", "Check edge gas-flow uniformity & edge purge", "Review RTA radial temperature profile"],
        "corrective": ["Replace focus ring", "Stabilize RF power delivery", "Rebalance edge gas flow", "Correct RTA radial profile"],
        "evidence_strength": "High",
    },
    "Loc": {
        "description": "A localized cluster of failing dies on the wafer interior (not centered, not a full edge feature).",
        "evidence": [
            ["Deposition", "Localized deposition anomaly", "Chamber flaking / spit deposits a local particle cluster", "Medium", "S1", "Heuristic"],
            ["Lithography (reticle)", "Reticle / mask defect", "A reticle particle repeats across ALL exposure fields, so a single local cluster is more often particle/chamber than reticle", "Low", "S1", "Textbook"],
            ["Handling", "Localized handling contact", "Spatial clusters indicate an assignable tool/step (statistical detection, not a specific physical attribution)", "Low", "S6", "Statistical"],
        ],
        "investigations": ["Particle-source / chamber-flaking check", "Reticle / pellicle inspection (look for a repeating-field signature)", "Cross-tool commonality analysis"],
        "corrective": ["Perform chamber clean (flaking)", "Clean / replace reticle or pellicle", "Remediate handling contact point"],
        "evidence_strength": "Medium",
    },
    "Near-full": {
        "description": "Failing dies cover most of the wafer.",
        "evidence": [
            ["Multiple modules (gross)", "Gross process excursion / missed step", "A missed or incorrect process step fails most of the wafer", "Medium", "S1", "Heuristic"],
            ["Lithography", "Gross dose / focus error", "A whole-wafer recipe error", "Medium", "S1", "Heuristic"],
            ["Test / Probe", "Probe / contact failure (test artifact)", "Probe-card / contact integrity can create wafer-wide systematic fail maps; rule this out before assigning a process cause", "Medium", "S6", "Statistical"],
        ],
        "investigations": ["Audit process log for a missed / incorrect step", "Verify recipe vs golden recipe", "Check probe-card / contact integrity (rule out test artifact)", "Gross-defect inspection"],
        "corrective": ["Reprocess / correct the missed step", "Restore golden recipe", "Service probe card", "Contamination remediation"],
        "evidence_strength": "Medium",
    },
    "Random": {
        "description": "Failing dies scattered across the wafer with no coherent spatial structure.",
        "evidence": [
            ["Line-wide", "Background killer-defect density (D0)", "Random defects follow defect-density / yield statistics (gamma-distributed defect density)", "High", "P6", "Primary"],
            ["Line-wide", "Defect clustering (negative-binomial statistics)", "Random defects are not purely Poisson; particle aggregates cluster, modelled by (generalized) negative-binomial statistics", "Medium-High", "P7", "Primary"],
            ["Line-wide (ambient)", "Random particulate contamination", "A cleanroom particle excursion deposits scattered killer defects", "Medium-High", "S1", "Textbook"],
            ["Facilities", "Airborne / chemical contamination", "FFU / filter degradation raises the ambient particle load", "Medium", "S1", "Heuristic"],
        ],
        "investigations": ["Defect-density (D0) monitoring & trend", "Cleanroom particle audit & FFU/filter check", "Chemical / airborne contamination review (treat as line-wide, not single-tool)"],
        "corrective": ["Drive a D0 reduction program", "Replace / service FFU & filters", "Remediate the chemical/airborne source"],
        "evidence_strength": "Medium-High",
    },
    "Scratch": {
        "description": "Failing dies along a line or curvilinear track.",
        "evidence": [
            ["CMP", "Mechanical scratch (pad debris / slurry agglomerate)", "Agglomerated slurry particles and conditioning-generated pad debris plough grooves (three-body abrasion)", "High", "P5", "Primary"],
            ["CMP", "Large / hard abrasive particle", "Oversized or harder particles cut deeper grooves into the surface", "Medium-High", "S5", "Review"],
            ["Handling / robotics", "Robot end-effector abrasion", "End-effector contact drags across the wafer surface", "Medium-High", "S1", "Heuristic"],
            ["Handling", "Carrier / cassette scrape", "Contact at a cassette / carrier point", "Medium", "S1", "Heuristic"],
        ],
        "investigations": ["Inspect CMP pad & slurry filtration", "Check slurry particle-size distribution (oversize/agglomerates)", "Check robot end-effector & handling path", "Inspect wafer carrier / cassette for contact points"],
        "corrective": ["Recondition / replace CMP pad; improve slurry filtration", "Tighten slurry filtration / large-particle control", "Service / replace end-effector", "Repair cassette contact point"],
        "evidence_strength": "High",
    },
    "none": {"description": "No defect signature detected (clean wafer).", "evidence": [], "investigations": [], "corrective": [], "evidence_strength": "N/A"},
}


# =====================================================================================
# 3. DASHBOARD BUILDER  (mechanism + provenance tier only; no inline quotes)
# =====================================================================================
def generate_rca_dashboard(defect_class, confidence_score):
    """Render the RCA dashboard with provenance tags. Verbatim source quotes are not
    embedded here by design -- see Just_RCA_reference_crosscheck_v3.md for quotes + pages."""
    v = RCA_KB.get(defect_class, {"description": "Unknown", "evidence": [], "investigations": [], "corrective": [], "evidence_strength": "N/A"})

    mod_html = "".join([f"<li>{m}</li>" for m in list(dict.fromkeys(r[0] for r in v["evidence"]))])
    chk_html = "".join([f"<li>{c}</li>" for c in v["investigations"]])
    action_html = "".join([f"<li>{c}</li>" for c in v["corrective"]])

    def prov_badge(r):
        cls = r[5].split()[0].lower().replace("*", "")
        return f"<span class='prov {cls}'>{r[5]}</span>"

    rows = "".join([
        f"<tr><td>{r[0]}</td><td><strong>{r[1]}</strong></td><td>{r[2]}</td>"
        f"<td><span class='badge {r[3].lower()}'>{r[3]}</span></td>"
        f"<td>{prov_badge(r)}</td><td>[{r[4]}]</td></tr>"
        for r in v["evidence"]
    ])

    used_ref_keys = list(dict.fromkeys([r[4] for r in v["evidence"]]))
    # primaries first (P*), then secondaries (S*), each in numeric order
    used_ref_keys.sort(key=lambda k: (k[0] != "P", int(k[1:])))
    ref_html = "".join([
        f"<li style='margin-bottom: 7px;'><strong>[{k}]</strong> {REFERENCES[k]['cite']} "
        f"<span class='prov {REFERENCES[k]['type'].split()[0].lower().replace('*','')}'>{REFERENCES[k]['type']}</span></li>"
        for k in used_ref_keys
    ])

    html = f"""
    <style>
        .rca-card {{ font-family: 'Segoe UI', Tahoma, sans-serif; max-width: 1040px; background: #fff; border: 1px solid #e1e4e8; border-radius: 8px; box-shadow: 0 4px 6px rgba(0,0,0,0.05); padding: 24px; margin-top: 10px; color: #24292e; }}
        .rca-header {{ display: flex; justify-content: space-between; align-items: center; border-bottom: 2px solid #f0f3f6; padding-bottom: 16px; margin-bottom: 16px; }}
        .rca-header h2 {{ margin: 0; color: #0366d6; font-size: 26px; }}
        .rca-metric .value {{ font-size: 22px; font-weight: bold; color: #28a745; text-align: right; }}
        .rca-caveat {{ background: #fff8e1; border: 1px solid #f0d58c; border-radius: 6px; padding: 10px 14px; font-size: 12.5px; color: #7a5b00; margin-bottom: 20px; }}
        .rca-grid {{ display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 20px; margin-bottom: 24px; }}
        .rca-section {{ background: #f6f8fa; padding: 16px; border-radius: 6px; }}
        .rca-section h4 {{ margin: 0 0 12px 0; color: #24292e; border-bottom: 1px solid #e1e4e8; padding-bottom: 8px; font-size: 14px; text-transform: uppercase; }}
        .rca-section ul {{ margin: 0; padding-left: 20px; font-size: 13.5px; line-height: 1.5; }}
        .rca-table {{ width: 100%; border-collapse: collapse; margin-top: 10px; font-size: 12.5px; }}
        .rca-table th, .rca-table td {{ padding: 9px 10px; text-align: left; border-bottom: 1px solid #e1e4e8; vertical-align: top; }}
        .rca-table th {{ font-size: 11px; text-transform: uppercase; color: #586069; }}
        .badge {{ padding: 3px 8px; border-radius: 12px; font-size: 11px; font-weight: bold; text-transform: uppercase; white-space: nowrap; }}
        .badge.high {{ background: #ffdce0; color: #cb2431; }} .badge.medium-high {{ background: #fff5b1; color: #b08800; }}
        .badge.medium {{ background: #dbedff; color: #0366d6; }} .badge.low {{ background: #f1f8ff; color: #586069; }}
        .prov {{ padding: 2px 7px; border-radius: 10px; font-size: 10.5px; font-weight: bold; white-space: nowrap; }}
        .prov.primary {{ background: #dafbe1; color: #1a7f37; }}
        .prov.textbook, .prov.monograph, .prov.review {{ background: #ddf4ff; color: #0969da; }}
        .prov.statistical {{ background: #fbefff; color: #8250df; }}
        .prov.heuristic, .prov.dataset {{ background: #eef1f4; color: #6e7781; }}
        .ref-section {{ background: white; border: 1px solid #e1e4e8; padding: 16px; border-radius: 6px; margin-top: 24px; }}
        .ref-section ul {{ list-style-type: none; padding-left: 0; font-size: 12.5px; color: #586069; }}
        .legend {{ font-size: 11.5px; color: #586069; margin-top: 10px; }}
    </style>

    <div class="rca-card">
        <div class="rca-header">
            <div>
                <h2>Defect Detected: {defect_class}</h2>
                <div style="font-size:14px; color:#586069; margin-top: 4px;">{v["description"]}</div>
            </div>
            <div class="rca-metric">
                <div class="value">{confidence_score*100:.1f}%</div>
                <div style="font-size:13px; color:#586069;">Model Confidence</div>
            </div>
        </div>

        <div class="rca-caveat">
            <strong>How to read this.</strong> RCA output is a <strong>ranked, literature-grounded hypothesis set</strong> &mdash; not a confirmed root cause.
            <span class="prov primary">Primary</span> marks a peer-reviewed research source verified against its PDF;
            <span class="prov textbook">Textbook</span>/<span class="prov monograph">Monograph</span>/<span class="prov review">Review</span> mark process-consensus knowledge;
            <span class="prov statistical">Statistical</span> marks methods that <em>detect</em> a pattern but do not establish its physical cause;
            <span class="prov heuristic">Heuristic</span> marks engineering practice with weaker sourcing.
            Verbatim quotes &amp; page numbers for every source are in the companion file <code>Just_RCA_reference_crosscheck_v3.md</code>.
            Confirm against fab FDC &amp; metrology before acting.
        </div>

        <div class="rca-grid">
            <div class="rca-section"><h4>Likely Process Modules</h4><ul>{mod_html}</ul></div>
            <div class="rca-section"><h4>Recommended Investigations</h4><ul>{chk_html}</ul></div>
            <div class="rca-section"><h4>Corrective Actions</h4><ul>{action_html}</ul></div>
        </div>

        <div class="rca-section" style="background:white; border:1px solid #e1e4e8;">
            <h4>Literature Evidence Traceability (Overall strength: {v["evidence_strength"]})</h4>
            <table class="rca-table">
                <thead><tr><th>Process Module</th><th>Physical Mechanism</th><th>Mechanistic Basis</th><th>Strength</th><th>Source Type</th><th>Cite</th></tr></thead>
                <tbody>{rows}</tbody>
            </table>
        </div>

        <div class="ref-section">
            <h4 style="margin: 0 0 12px 0; color: #24292e; border-bottom: 1px solid #e1e4e8; padding-bottom: 8px; font-size: 14px; text-transform: uppercase;">Literature References</h4>
            <ul>{ref_html}</ul>
            <div class="legend">Defect-pattern taxonomy follows the WM-811K dataset (Wu et al. 2015, [S7]); used for pattern definitions only, never as evidence for a physical cause.</div>
        </div>
    </div>
    """
    display(HTML(html))


# ---------------------------------------------------------
# EXECUTE
# ---------------------------------------------------------
generate_rca_dashboard(detected_class, detected_confidence)
# Out:
#     <style>
#         .rca-card { font-family: 'Segoe UI', Tahoma, sans-serif; max-width: 1040px; background: #fff; border: 1px solid #e1e4e8; border-radius: 8px; box-shadow: 0 4px 6px rgba(0,0,0,0.05); padding: 24px; margin-top: 10px; color: #24292e; }
#         .rca-header { display: flex; justify-content: space-between; align-items: center; border-bottom: 2px solid #f0f3f6; padding-bottom: 16px; margin-bottom: 16px; }
#         .rca-header h2 { margin: 0; color: #0366d6; font-size: 26px; }
#         .rca-metric .value { font-size: 22px; font-weight: bold; color: #28a745; text-align: right; }
#         .rca-caveat { background: #fff8e1; border: 1px solid #f0d58c; border-radius: 6px; padding: 10px 14px; font-size: 12.5px; color: #7a5b00; margin-bottom: 20px; }
#         .rca-grid { display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 20px; margin-bottom: 24px; }
#         .rca-section { background: #f6f8fa; padding: 16px; border-radius: 6px; }
# ...
